# %%
import numpy as np
from datascience import *

# %%
farmers_markets = Table.read_table('farmers_markets.csv')

# %%
farmers_markets.show
# Out:
# <bound method Table.show of FMID    | MarketName                                       | street                                                   | city       | County               | State                | zip   | x        | y       | Website                                               | Facebook                                                     | Twitter                             | Youtube | OtherMedia                                                   | Organic | Tofu | Bakedgoods | Cheese | Crafts | Flowers | Eggs | Seafood | Herbs | Vegetables | Honey | Jams | Maple | Meat | Nursery | Nuts | Plants | Poultry | Prepared | Soap | Trees | Wine | Coffee | Beans | Fruits | Grains | Juices | Mushrooms | PetFood | WildHarvested | updateTime            | Location                                                   | Credit | WIC  | WICcash | SFMNP | SNAP | Season1Date              | Season1Time                                  | Season2Date | Season2Time | Season3Date | Season3Time |
# ...

# %%
farmers_markets
# Out:
# FMID    | MarketName                                       | street                                                   | city       | County               | State                | zip   | x        | y       | Website                                               | Facebook                                                     | Twitter                             | Youtube | OtherMedia                                                   | Organic | Tofu | Bakedgoods | Cheese | Crafts | Flowers | Eggs | Seafood | Herbs | Vegetables | Honey | Jams | Maple | Meat | Nursery | Nuts | Plants | Poultry | Prepared | Soap | Trees | Wine | Coffee | Beans | Fruits | Grains | Juices | Mushrooms | PetFood | WildHarvested | updateTime            | Location                                                   | Credit | WIC  | WICcash | SFMNP | SNAP | Season1Date              | Season1Time                                  | Season2Date | Season2Time | Season3Date | Season3Time | Season4Date | Season4Time
# ...

# %%
farmers_markets.show(5)
# Out:
# <table border="1" class="dataframe">
#     <thead>
#         <tr>
# ...

# %% [markdown]
# farmers_markets.num_columns

# %%
farmers_markets.show(5)
# Out:
# <table border="1" class="dataframe">
#     <thead>
#         <tr>
# ...

# %%
print(farmers_markets.num_columns)
# Out:
# 59

# %%
num_farmers_rows = farmers_markets.num_rows
print("The table has" , num_farmers_rows , "rows in it")
# Out:
# The table has 8546 rows in it

# %%
farmers_markets.select('MarketName','x','y')
# Out:
# MarketName                                       | x        | y
#  Caledonia Farmers Market Association - Danville | -72.1403 | 44.411
#  Stearns Homestead Farmers' Market               | -81.7286 | 41.3751
# 100 Mile Market                                  | -85.5749 | 42.296
# 106 S. Main Street Farmers Market                | -82.8187 | 34.8042
# 10th Steet Community Farmers Market              | -94.2746 | 37.4956
# 112st Madison Avenue                             | -73.9493 | 40.7939
# 12 South Farmers Market                          | -86.7907 | 36.1184
# 125th Street Fresh Connect Farmers' Market       | -73.9482 | 40.809
# 12th & Brandywine Urban Farm Market              | -75.5345 | 39.7421
# 14&U Farmers' Market                             | -77.0321 | 38.917
# ... (8536 rows omitted)

# %%
farmers_markets_locations = farmers_markets.select('MarketName','x','y')
farmers_markets_locations
# Out:
# MarketName                                       | x        | y
#  Caledonia Farmers Market Association - Danville | -72.1403 | 44.411
#  Stearns Homestead Farmers' Market               | -81.7286 | 41.3751
# 100 Mile Market                                  | -85.5749 | 42.296
# 106 S. Main Street Farmers Market                | -82.8187 | 34.8042
# 10th Steet Community Farmers Market              | -94.2746 | 37.4956
# 112st Madison Avenue                             | -73.9493 | 40.7939
# 12 South Farmers Market                          | -86.7907 | 36.1184
# 125th Street Fresh Connect Farmers' Market       | -73.9482 | 40.809
# 12th & Brandywine Urban Farm Market              | -75.5345 | 39.7421
# 14&U Farmers' Market                             | -77.0321 | 38.917
# ... (8536 rows omitted)

# %%
farmers_markets_without_fmid = farmers_markets.drop('FMID','updateTime')
farmers_markets_without_fmid
# Out:
# MarketName                                       | street                                                   | city       | County               | State                | zip   | x        | y       | Website                                               | Facebook                                                     | Twitter                             | Youtube | OtherMedia                                                   | Organic | Tofu | Bakedgoods | Cheese | Crafts | Flowers | Eggs | Seafood | Herbs | Vegetables | Honey | Jams | Maple | Meat | Nursery | Nuts | Plants | Poultry | Prepared | Soap | Trees | Wine | Coffee | Beans | Fruits | Grains | Juices | Mushrooms | PetFood | WildHarvested | Location                                                   | Credit | WIC  | WICcash | SFMNP | SNAP | Season1Date              | Season1Time                                  | Season2Date | Season2Time | Season3Date | Season3Time | Season4Date | Season4Time
# ...

# %%
farmers_markets.sort('x')
# Out:
# FMID    | MarketName                                     | street                        | city          | County   | State  | zip   | x        | y       | Website                   | Facebook                                          | Twitter | Youtube | OtherMedia | Organic | Tofu | Bakedgoods | Cheese | Crafts | Flowers | Eggs | Seafood | Herbs | Vegetables | Honey | Jams | Maple | Meat | Nursery | Nuts | Plants | Poultry | Prepared | Soap | Trees | Wine | Coffee | Beans | Fruits | Grains | Juices | Mushrooms | PetFood | WildHarvested | updateTime            | Location | Credit | WIC  | WICcash | SFMNP | SNAP | Season1Date | Season1Time | Season2Date | Season2Time | Season3Date | Season3Time | Season4Date | Season4Time
# ...

# %%
farmers_markets_locations.sort('x',descending=True)
# Out:
# MarketName                                  | x        | y
# Christian "Shan" Hendricks Vegetable Market | -64.7043 | 17.7449
# La Reine Farmers Market                     | -64.7789 | 17.7322
# Anne Heyliger Vegetable Market              | -64.8799 | 17.7099
# Rothschild Francis Vegetable Market         | -64.9326 | 18.3428
# Feria Agrícola de Luquillo                  | -65.7207 | 18.3782
# El Mercado Familiar                         | -65.9674 | 18.1871
# El Mercado Familiar                         | -65.9786 | 18.2526
# El Mercado Familiar                         | -66.0135 | 18.0069
# El Mercado Familiar                         | -66.039  | 18.2324
# El Maercado Familiar                        | -66.0617 | 17.9686
# ... (8536 rows omitted)

# %%
california_farmers_markets = farmers_markets.where('State',are.equal_to('California'))
california_farmers_markets
# Out:
# FMID    | MarketName                               | street                      | city         | County         | State      | zip   | x        | y       | Website                                                 | Facebook                                       | Twitter                         | Youtube | OtherMedia                   | Organic | Tofu | Bakedgoods | Cheese | Crafts | Flowers | Eggs | Seafood | Herbs | Vegetables | Honey | Jams | Maple | Meat | Nursery | Nuts | Plants | Poultry | Prepared | Soap | Trees | Wine | Coffee | Beans | Fruits | Grains | Juices | Mushrooms | PetFood | WildHarvested | updateTime            | Location                          | Credit | WIC  | WICcash | SFMNP | SNAP | Season1Date              | Season1Time                                | Season2Date              | Season2Time           | Season3Date              | Season3Time           | Season4Date | Season4Time
# ...

# %%
berkeley_markets = california_farmers_markets.where('city',are.equal_to('Berkeley'))
berkeley_markets
# Out:
# FMID    | MarketName                        | street                                     | city     | County  | State      | zip   | x        | y       | Website                         | Facebook | Twitter                   | Youtube | OtherMedia | Organic | Tofu | Bakedgoods | Cheese | Crafts | Flowers | Eggs | Seafood | Herbs | Vegetables | Honey | Jams | Maple | Meat | Nursery | Nuts | Plants | Poultry | Prepared | Soap | Trees | Wine | Coffee | Beans | Fruits | Grains | Juices | Mushrooms | PetFood | WildHarvested | updateTime           | Location | Credit | WIC  | WICcash | SFMNP | SNAP | Season1Date              | Season1Time            | Season2Date | Season2Time | Season3Date | Season3Time | Season4Date | Season4Time
# ...

# %%
imdb = Table.read_table('imdb.csv')
imdb
# Out:
# Votes  | Rating | Title                 | Year | Decade
# 88355  | 8.4    | M                     | 1931 | 1930
# 132823 | 8.3    | Singin' in the Rain   | 1952 | 1950
# 74178  | 8.3    | All About Eve         | 1950 | 1950
# 635139 | 8.6    | Léon                  | 1994 | 1990
# 145514 | 8.2    | The Elephant Man      | 1980 | 1980
# 425461 | 8.3    | Full Metal Jacket     | 1987 | 1980
# 441174 | 8.1    | Gone Girl             | 2014 | 2010
# 850601 | 8.3    | Batman Begins         | 2005 | 2000
# 37664  | 8.2    | Judgment at Nuremberg | 1961 | 1960
# 46987  | 8      | Relatos salvajes      | 2014 | 2010
# ... (240 rows omitted)

# %%
above_eight = imdb.where('Year',are.between_or_equal_to(2010, 2015)).where('Rating',are.above(8)).select('Title','Rating')
above_eight
# Out:
# Title                    | Rating
# Gone Girl                | 8.1
# Warrior                  | 8.2
# Intouchables             | 8.5
# Shutter Island           | 8.1
# 12 Years a Slave         | 8.1
# Inside Out (2015/I)      | 8.5
# Jagten                   | 8.2
# Toy Story 3              | 8.3
# How to Train Your Dragon | 8.1
# Interstellar             | 8.6
# ... (10 rows omitted)

# %%
proportion_in_20th_century = imdb.where('Year',are.between_or_equal_to(1900,1990)).num_rows/imdb.num_rows
proportion_in_21st_century = imdb.where('Year',are.between_or_equal_to(2000,2026)).num_rows/imdb.num_rows
print("Proportion in 20th century:", proportion_in_20th_century)
print("Proportion in 21st century:", proportion_in_21st_century)
# Out:
# Proportion in 20th century: 0.52
# Proportion in 21st century: 0.316
